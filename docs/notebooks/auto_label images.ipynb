from ultralytics import YOLO
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.

# %%
# ===== Configuration =====
# Model settings
MODEL_PATH = "yolo_12n_best.pt"  # Path to your finetuned model
MODEL_IMG_SIZE = 704  # Image size for YOLO model

# Path settings
RECORDINGS_PATH = "Training"  # Path to recordings folder
RESULTS_PATH = "annotations_nocrop"  # Path to save results
SHOULD_CROP = False  # Whether to crop images to ROI

SAVE_PROGRESS_INTERVAL = 100  # Save progress every X images

# Vehicle classes - adjust based on your model
# Format: {class_id: {'name': 'class_name', 'confidence': threshold}}
CLASS_CONFIG = {
    0: {"name": "person", "confidence": 0.3},
    1: {"name": "vehicle.car", "confidence": 0.3},
    2: {"name": "vehicle.truck", "confidence": 0.3},
    3: {"name": "vehicle.motorcycle", "confidence": 0.3},
    4: {"name": "vehicle.bus", "confidence": 0.3},
    5: {"name": "trafficcone", "confidence": 0.3},
}

# We use these custom ROIs because for each recording, the camera angle differs a slight bit.
# This ensures that the region of interest matches the relevant area in each dataset.
RECORDINGS_ROIS_MAP = {
    # Example: "recording_name": [x1, y1, width, height]
    "2024-12-19_11-50-15": (0, 320, 1920, 575),
    "2024-12-19_12-58-38": (0, 320, 1920, 575),
    "2025-04-03_19-33-31": (0, 256, 1920, 575),
    "2025-04-03_21-05-24": (0, 240, 1920, 575),
    "2025-04-03_21-53-03": (0, 245, 1920, 575),
}

# %%
def setup():
    """Initialize device and model"""
    # Set up device for inference
    device = "cuda" if torch.cuda.is_available() else "cpu"
    print(f"Using device: {device}")

    # Load model
    print(f"Loading YOLO model from: {MODEL_PATH}")
    model = YOLO(MODEL_PATH, task="detect")
    print("Model loaded successfully!")

    vehicle_classes = list(CLASS_CONFIG.keys())[
        1:
    ]  # Skip class 0 (person), as it's not relevant on the autobahn
    print(f"Using custom vehicle classes: {vehicle_classes}")

    return model, device, vehicle_classes

# Initialize model and device
model, device, vehicle_classes = setup()
# Out:
# Using device: cuda
# Loading YOLO model from: yolo_12n_best.pt
# Model loaded successfully!
# Using custom vehicle classes: [1, 2, 3, 4, 5]

# %%
def get_recording_dirs(recordings_path=RECORDINGS_PATH):
    """Get all recording directories"""
    recording_dirs = sorted([d for d in Path(recordings_path).iterdir() if d.is_dir()])

    if not recording_dirs:
        print(f"No recording directories found in {recordings_path}")
        return []

    print(f"Found {len(recording_dirs)} recording directories:")
    for i, dir_path in enumerate(recording_dirs):
        print(f"{i+1}: {dir_path.name}")

    return recording_dirs

# Get all recording directories
recording_dirs = get_recording_dirs()
# recording_dirs = recording_dirs[:1]  # For testing, process only the first directory

if not recording_dirs:
    print("No recording directories found. Exiting.")
# Out:
# Found 5 recording directories:
# 1: 2024-12-19_11-50-15
# 2: 2024-12-19_12-58-38
# 3: 2025-04-03_19-33-31
# 4: 2025-04-03_21-05-24
# 5: 2025-04-03_21-53-03

# %%
DEFAULT_IMAGE_ROI = (0, 320, 1920, 580)
def crop_to_roi(image, roi=None):
    if image is None:
        return None

    # Default ROI optimized for highway driving
    if roi is None:
        roi = DEFAULT_IMAGE_ROI

    x, y, width, height = roi

    # Safety checks for image boundaries
    img_height, img_width = image.shape[:2]
    x = max(0, min(x, img_width - 1))
    y = max(0, min(y, img_height - 1))
    width = min(width, img_width - x)
    height = min(height, img_height - y)

    # Crop the image
    return image[y : y + height, x : x + width]

# %%
def process_directory(recording_dir, model, device, vehicle_classes, crops=True):
    # Get all jpg files in the directory
    image_files = sorted(list(Path(recording_dir).glob("*.jpg")))
    # image_files = image_files[:5]  # For testing, process only the first 10 images

    telemetry_timestamps = pd.read_csv(recording_dir / "telemetry.csv")["Time"].astype(str)
    telemetry_timestamps = list(pd.read_csv(recording_dir / "telemetry.csv")["Time"].astype(str))
    print(f"Found {len(telemetry_timestamps)} timestamps in {recording_dir}")

    if not image_files:
        print(f"No jpg files found in {recording_dir}")
        return None

    total_images = len(image_files)
    print(f"Found {total_images} jpg files in {recording_dir}")

    # Create annotations dataframe
    annotations_df = pd.DataFrame(
        columns=[
            "Time",
            "filename",
            "vehicle_count",
            "class_ids",
            "confidences",
            "bboxes",
            "areas",
        ]
    )

    # Process each image
    start_time = time.time()
    for i, img_path in enumerate(
        tqdm(image_files, desc=f"Processing {recording_dir.name}")
    ):
        # Extract timestamp from filename (remove extension)
        filename = img_path.name
        timestamp = filename.split(".")[0]

        # Read the image
        img = cv2.imread(str(img_path))
        if img is None:
            print(f"Failed to read image: {img_path}")
            continue

        if timestamp not in telemetry_timestamps:
            print(f"Timestamp {timestamp} not found in telemetry.csv")
            continue

        # Convert BGR to RGB and crop to ROI
        # img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB) # images are already saved in RGB
        if crops:
          roi_for_recording = RECORDINGS_ROIS_MAP.get(recording_dir.name, None)
          img_cropped = crop_to_roi(img, roi_for_recording)
        else:
          img_cropped = img.copy()

        if img_cropped is None:
            print(f"Failed to crop image: {img_path}")
            continue

        # Run detection with base confidence (we'll filter by class-specific confidence later)
        # Use lowest confidence threshold from CLASS_CONFIG to catch all potential detections
        base_confidence = min([cfg["confidence"] for cfg in CLASS_CONFIG.values()])
        results = model(
            img_cropped,
            conf=base_confidence,
            device=device,
            imgsz=MODEL_IMG_SIZE,
            verbose=False,
        )

        # Process detections with class-specific confidence thresholds
        class_ids = []
        confidences = []
        bboxes = []
        areas = []

        for result in results:
            boxes = result.boxes
            for box in boxes:
                cls_id = int(box.cls.item())
                conf = float(box.conf.item())

                # Only consider vehicle classes and apply class-specific confidence threshold
                if (
                    cls_id in vehicle_classes
                    and cls_id in CLASS_CONFIG
                    and conf >= CLASS_CONFIG[cls_id]["confidence"]
                ):
                    x1, y1, x2, y2 = box.xyxy[0].tolist()
                    area = (x2 - x1) * (y2 - y1)

                    class_ids.append(cls_id)
                    confidences.append(conf)
                    bboxes.append([float(x1), float(y1), float(x2), float(y2)])
                    areas.append(float(area))

        # Add row to dataframe
        annotations_df.loc[len(annotations_df)] = [
            timestamp,
            filename,
            len(class_ids),
            str(class_ids),
            str(confidences),
            str(bboxes),
            str(areas),
        ]

        # Save progress periodically
        if (i + 1) % SAVE_PROGRESS_INTERVAL == 0 or i == total_images - 1:
            annotations_path = Path(recording_dir) / "annotations.csv"
            annotations_df.to_csv(annotations_path, index=False)
            elapsed_time = time.time() - start_time

    # Save final annotations to CSV
    annotations_path = Path(recording_dir) / "annotations.csv"
    annotations_df.to_csv(annotations_path, index=False)
    print(f"✅ Annotations saved to {annotations_path}")

    # Print statistics
    elapsed_time = time.time() - start_time
    print(f"Processing time: {elapsed_time:.2f} seconds")
    print(f"Processing speed: {total_images / elapsed_time:.2f} images/second")
    print(f"Total vehicles detected: {annotations_df['vehicle_count'].sum()}")

    return annotations_path

# %%
import os
import shutil

# shutil.rmtree("annotations")
for i, recording_dir in enumerate(recording_dirs):
    print(
        f"\nProcessing directory {i+1}/{len(recording_dirs)}: {recording_dir.name}"
    )
    # Copy telemetry.csv and annotations.csv to the results directory
    annotations_path = process_directory(
        recording_dir, model, device, vehicle_classes, crops=SHOULD_CROP
    )
    telemetry_path = recording_dir / "telemetry.csv"

    # Save to results/[timestamp]
    results_dir = Path(RESULTS_PATH) / recording_dir.name
    results_dir.mkdir(parents=True, exist_ok=True)

    telemetry_copy_path = results_dir / "telemetry.csv"
    annotations_copy_path = results_dir / "annotations.csv"
    telemetry_copy_path.write_text(telemetry_path.read_text())
    annotations_copy_path.write_text(annotations_path.read_text())
# Out:
# Processing directory 1/5: 2024-12-19_11-50-15
# Found 6900 timestamps in Training/2024-12-19_11-50-15
# Found 6900 jpg files in Training/2024-12-19_11-50-15
# Processing 2024-12-19_11-50-15: 100%|██████████| 6900/6900 [04:18<00:00, 26.73it/s]
# ✅ Annotations saved to Training/2024-12-19_11-50-15/annotations.csv
# Processing time: 258.26 seconds
# Processing speed: 26.72 images/second
# Total vehicles detected: 18665
#
# Processing directory 2/5: 2024-12-19_12-58-38
# Found 3757 timestamps in Training/2024-12-19_12-58-38
# Found 3757 jpg files in Training/2024-12-19_12-58-38
# Processing 2024-12-19_12-58-38: 100%|██████████| 3757/3757 [02:17<00:00, 27.24it/s]
# ✅ Annotations saved to Training/2024-12-19_12-58-38/annotations.csv
# Processing time: 137.98 seconds
# Processing speed: 27.23 images/second
# Total vehicles detected: 8113
#
# Processing directory 3/5: 2025-04-03_19-33-31
# Found 8366 timestamps in Training/2025-04-03_19-33-31
# Found 8366 jpg files in Training/2025-04-03_19-33-31
# Processing 2025-04-03_19-33-31: 100%|██████████| 8366/8366 [05:10<00:00, 26.96it/s]
# ✅ Annotations saved to Training/2025-04-03_19-33-31/annotations.csv
# Processing time: 310.44 seconds
# Processing speed: 26.95 images/second
# Total vehicles detected: 21038
#
# Processing directory 4/5: 2025-04-03_21-05-24
# Found 763 timestamps in Training/2025-04-03_21-05-24
# Found 763 jpg files in Training/2025-04-03_21-05-24
# Processing 2025-04-03_21-05-24: 100%|██████████| 763/763 [00:26<00:00, 28.53it/s]
# ✅ Annotations saved to Training/2025-04-03_21-05-24/annotations.csv
# Processing time: 26.76 seconds
# Processing speed: 28.51 images/second
# Total vehicles detected: 3021
#
# Processing directory 5/5: 2025-04-03_21-53-03
# Found 6802 timestamps in Training/2025-04-03_21-53-03
# Found 6802 jpg files in Training/2025-04-03_21-53-03
# Processing 2025-04-03_21-53-03: 100%|██████████| 6802/6802 [04:03<00:00, 27.90it/s]
# ✅ Annotations saved to Training/2025-04-03_21-53-03/annotations.csv
# Processing time: 243.92 seconds
# Processing speed: 27.89 images/second
# Total vehicles detected: 15644

# %%
# Total training images processed
total = 0
for recording_dir in recording_dirs:
  annotations_path = Path(recording_dir) / "annotations.csv"
  annotations_df = pd.read_csv(annotations_path)
  print(f"Total images processed for {recording_dir}: {len(annotations_df)}")
  total += len(annotations_df)
print(f"Total images processed: {total}")
# Out:
# Total images processed for Training/2024-12-19_11-50-15: 6900
# Total images processed for Training/2024-12-19_12-58-38: 3757
# Total images processed for Training/2025-04-03_19-33-31: 8366
# Total images processed for Training/2025-04-03_21-05-24: 763
# Total images processed for Training/2025-04-03_21-53-03: 6802
# Total images processed: 26588

# %%
# !zip -r annotations.zip annotations
# !zip -r annotations_nocrop.zip annotations_nocrop
# Out:
#   adding: annotations/ (stored 0%)
#   adding: annotations/2024-12-19_12-58-38/ (stored 0%)
#   adding: annotations/2024-12-19_12-58-38/telemetry.csv (deflated 87%)
#   adding: annotations/2024-12-19_12-58-38/annotations.csv (deflated 64%)
#   adding: annotations/2024-12-19_11-50-15/ (stored 0%)
#   adding: annotations/2024-12-19_11-50-15/telemetry.csv (deflated 86%)
#   adding: annotations/2024-12-19_11-50-15/annotations.csv (deflated 63%)
#   adding: annotations/2025-04-03_21-53-03/ (stored 0%)
#   adding: annotations/2025-04-03_21-53-03/telemetry.csv (deflated 86%)
#   adding: annotations/2025-04-03_21-53-03/annotations.csv (deflated 64%)
#   adding: annotations/2025-04-03_19-33-31/ (stored 0%)
#   adding: annotations/2025-04-03_19-33-31/telemetry.csv (deflated 87%)
#   adding: annotations/2025-04-03_19-33-31/annotations.csv (deflated 64%)
#   adding: annotations/2025-04-03_21-05-24/ (stored 0%)
#   adding: annotations/2025-04-03_21-05-24/telemetry.csv (deflated 86%)
#   adding: annotations/2025-04-03_21-05-24/annotations.csv (deflated 63%)
#   adding: annotations_nocrop/ (stored 0%)
#   adding: annotations_nocrop/2024-12-19_12-58-38/ (stored 0%)
#   adding: annotations_nocrop/2024-12-19_12-58-38/telemetry.csv (deflated 87%)
#   adding: annotations_nocrop/2024-12-19_12-58-38/annotations.csv (deflated 65%)
#   adding: annotations_nocrop/2024-12-19_11-50-15/ (stored 0%)
#   adding: annotations_nocrop/2024-12-19_11-50-15/telemetry.csv (deflated 86%)
#   adding: annotations_nocrop/2024-12-19_11-50-15/annotations.csv (deflated 64%)
#   adding: annotations_nocrop/2025-04-03_21-53-03/ (stored 0%)
#   adding: annotations_nocrop/2025-04-03_21-53-03/telemetry.csv (deflated 86%)
#   adding: annotations_nocrop/2025-04-03_21-53-03/annotations.csv (deflated 65%)
#   adding: annotations_nocrop/2025-04-03_19-33-31/ (stored 0%)
#   adding: annotations_nocrop/2025-04-03_19-33-31/telemetry.csv (deflated 87%)
#   adding: annotations_nocrop/2025-04-03_19-33-31/annotations.csv (deflated 65%)
#   adding: annotations_nocrop/2025-04-03_21-05-24/ (stored 0%)
#   adding: annotations_nocrop/2025-04-03_21-05-24/telemetry.csv (deflated 86%)
#   adding: annotations_nocrop/2025-04-03_21-05-24/annotations.csv (deflated 64%)
